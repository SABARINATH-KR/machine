# %% [markdown]
# <a href="https://colab.research.google.com/github/SABARINATH-KR/machine/blob/main/ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr1 = np.array([3,7,5])
arr2 = np.array([10,20,90])

# %%
a = arr1 + arr2
print(a)
# Out:
# [13 27 95]

# %%
b = arr1 * arr2
print(b)
# Out:
# [ 30 140 450]

# %%
c = arr1 /arr2
print(c)
# Out:
# [0.3        0.35       0.05555556]

# %%
d = arr2 - arr1
print(d)
# Out:
# [ 7 13 85]

# %%
e = arr1 % arr2
print(e)
# Out:
# [3 7 5]

# %% [markdown]
# MIN MAX

# %%
print(np.min(arr1))
print(np.max(arr1))
# Out:
# 3
# 7

# %%
print(arr1+2)
# Out:
# [5 9 7]

# %%
print(arr1.reshape(1,3))
# Out:
# [[3 7 5]]

# %%
print(arr2[1:])
# Out:
# [20 90]

# %%
print(np.sum(arr2))
print(np.mean(arr2))
# Out:
# 120
# 40.0

# %%
print(np.concatenate([arr1,arr2]))
# Out:
# [ 3  7  5 10 20 90]

# %%
arr1 < arr2
# Out:
# array([ True,  True,  True])

# %%
arr1>arr2
# Out:
# array([False, False, False])

# %% [markdown]
# Pandas

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/ML ADD ON/brisbane_water_quality.csv")
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30894 entries, 0 to 30893
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Timestamp                                 30894 non-null  object
#  1   Record number                             30894 non-null  int64
#  2   Average Water Speed                       30874 non-null  float64
#  3   Average Water Direction                   30893 non-null  float64
#  4   Chlorophyll                               30309 non-null  float64
#  5   Chlorophyll [quality]                     30086 non-null  float64
#  6   Temperature                               25730 non-null  float64
#  7   Temperature [quality]                     25550 non-null  float64
#  8   Dissolved Oxygen                          26594 non-null  float64
#  9   Dissolved Oxygen [quality]                26370 non-null  float64
# ...

# %%
data.dropna(subset=["pH"],inplace=True)

# %%
data["purity"] = (data["pH"] ==7) & (data["Dissolved Oxygen"] >5)

# %%
data.head()
# Out:
#              Timestamp  Record number  Average Water Speed  \
# 0  2023-08-04 23:00:00           1468                4.834
# 1  2023-08-04 23:30:00           1469                2.544
# 2  2023-08-04 23:00:00           1470                1.260
# 3  2023-08-04 23:30:00           1471                0.760
# 4  2023-08-04 23:00:00           1472                3.397
#
#    Average Water Direction  Chlorophyll  Chlorophyll [quality]  Temperature  \
# 0                   73.484        1.621                    NaN       20.018
# 1                  106.424        1.959                    NaN       19.986
# 2                  156.755        1.620                    NaN       20.001
# 3                  281.754        1.761                    NaN       19.983
# 4                  244.637        1.635                    NaN       19.986
#
#    Temperature [quality]  Dissolved Oxygen  Dissolved Oxygen [quality]  ...  \
# ...

# %% [markdown]
# Data preparation for ML Models

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['Dissolved Oxygen','pH','Chlorophyll']]
y = data["Temperature"]

# %%
x.shape
# Out:
# (25681, 3)

# %%
y.shape
# Out:
# (25681,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20544, 3)
# (5137, 3)
# (20544,)
# (5137,)

# %%
import pandas as pd
import matplotlib.pyplot as plt
data ={"name":["Alice","bob","charlie","david"],"study hours":[40, 30, 50, 20],"pass/fail":["pass","fail","pass","fail"]}
df = pd.DataFrame(data)
df
# Out:
#       name  study hours pass/fail
# 0    Alice           40      pass
# 1      bob           30      fail
# 2  charlie           50      pass
# 3    david           20      fail

# %%
# @title study hours

from matplotlib import pyplot as plt
df['study hours'].plot(kind='line', figsize=(8, 4), title='study hours')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
x = df[["study hours"]]
y = df["pass/fail"]

# %%
x.head()
# Out:
#    study hours
# 0           40
# 1           30
# 2           50
# 3           20

# %%
new_study_hours = int(input("Enter new study hours: "))
predicted_outcome ="pass" if new_study_hours >= 35 else "fail"
print("Predicted outcome:for",new_study_hours,"hours:", predicted_outcome)
# Out:
# Enter new study hours: 50
# Predicted outcome:for 50 hours: pass

# %%
plt.scatter(x,y)
plt.scatter(new_study_hours,predicted_outcome,marker="*",color="red")
plt.xlabel("Study Hours")
plt.ylabel("pass/fail")
plt.title("predicting course outcome")
plt.legend()
plt.show()
plt
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data ={"name":["Alice","bob","charlie","meena","monisha","jack","david"],"Hair length":[40, 30, 35, 26, 52, 49, 55],
 "lip-stick":[90,10,10,100,85,25,20],
  "facial-hair":[10,70,80,5,20,77,100],
  "gender":["female","male","male","female","female","male","male"]
}
df = pd.DataFrame(data)
df
# Out:
#       name  Hair length  lip-stick  facial-hair  gender
# 0    Alice           40         90           10  female
# 1      bob           30         10           70    male
# 2  charlie           35         10           80    male
# 3    meena           26        100            5  female
# 4  monisha           52         85           20  female
# 5     jack           49         25           77    male
# 6    david           55         20          100    male

# %%
Hairlength = int(input("Enter Hair length: "))
lip_stick = int(input("Enter lip-stick: "))
facial_hair = int(input("Enter facial-hair: "))
predicted_outcome ="male" if (Hairlength<= 50 and lip_stick<50 and facial_hair >50)  else "female"
print("Predicted outcome:", predicted_outcome)
# Out:
# Enter Hair length: 50
# Enter lip-stick: 10
# Enter facial-hair: 80
# Predicted outcome: male

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("/content/drive/MyDrive/ML ADD ON/brisbane_water_quality.csv")
data.head()
# Out:
#              Timestamp  Record number  Average Water Speed  \
# 0  2023-08-04 23:00:00           1468                4.834
# 1  2023-08-04 23:30:00           1469                2.544
# 2  2023-08-04 23:00:00           1470                1.260
# 3  2023-08-04 23:30:00           1471                0.760
# 4  2023-08-04 23:00:00           1472                3.397
#
#    Average Water Direction  Chlorophyll  Chlorophyll [quality]  Temperature  \
# 0                   73.484        1.621                    NaN       20.018
# 1                  106.424        1.959                    NaN       19.986
# 2                  156.755        1.620                    NaN       20.001
# 3                  281.754        1.761                    NaN       19.983
# 4                  244.637        1.635                    NaN       19.986
#
#    Temperature [quality]  Dissolved Oxygen  Dissolved Oxygen [quality]  \
# 0                    NaN             7.472                         NaN
# ...

# %%
features = data[["pH","Dissolved Oxygen"]]
features.head()
# Out:
#       pH  Dissolved Oxygen
# 0  8.176             7.472
# 1  8.175             7.455
# 2  8.171             7.430
# 3  8.171             7.419
# 4  8.171             7.429

# %%
features.dropna(subset=["pH"],inplace=True)
features.dropna(subset=["Dissolved Oxygen"],inplace=True)
# Out:
# <ipython-input-7-2d14ba5a1457>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.dropna(subset=["pH"],inplace=True)
# <ipython-input-7-2d14ba5a1457>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.dropna(subset=["Dissolved Oxygen"],inplace=True)

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
wcss = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i,init="k-means++",random_state=42)
  kmeans.fit(scaled_features)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmeans = KMeans(n_clusters=10,init="k-means++",random_state=42)
kmeans.fit(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=10, random_state=42)

# %%
features["cluster"] = kmeans.labels_
# Out:
# <ipython-input-24-c1e60079a688>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features["cluster"] = kmeans.labels_

# %%
features.head()
# Out:
#       pH  Dissolved Oxygen  cluster
# 0  8.176             7.472        1
# 1  8.175             7.455        1
# 2  8.171             7.430        9
# 3  8.171             7.419        9
# 4  8.171             7.429        9

# %%
plt.figure(figsize=(8,4))
plt.scatter(features["pH"],features["Dissolved Oxygen"],c=features["cluster"])
plt.title("K-Means Clustering")
plt.xlabel("pH")
plt.ylabel("Dissolved Oxygen")
plt.show()
